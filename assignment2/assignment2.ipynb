# %%
import jieba
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
from wordcloud import WordCloud

# %%
df = pd.read_csv('AO3.csv')

# %%
words = df['movie_name'].tolist()

# %%
words = ','.join(words)

# %% [markdown]
# **what genre of films are popular in AO3 ?**
#
# As we can see from the film-name wordcloud, AO3 fans are so into love movies and hero movies. And sci-fi and advanture films are also welcomed by  AO3.

# %%
import wordcloud
wordcloud = WordCloud(max_font_size=120,mode='RGBA',background_color='white',random_state=42,width=600,height=400,max_words=200).generate(words)
plt.figure(figsize=(12,12))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
yearplt.show()

# %%
for i in range(len(df2['numbers'])):
    df2['numbers']=pd.to_numeric(df2['numbers'])

# %%
df3 = df2[['movie_name','numbers']].sort_values(by='numbers',ascending=False)
df3 = df3[:20]
df3

# %%
import plotly
import plotly.graph_objs as go

data = [go.Bar(x=df3.movie_name,
            y=df3.numbers)]
plotly.offline.plot(data, filename='favorite films')

# %% [markdown]
# **What film is the most attractive?**
#
# Obviously Marvel fans are the most productive. They have uppload above 250k fandoms for this comic brand. Marvel cinematic univers, the Avengers and The Avengers(Marvel), as 3 different parallel univers in Marvel world, rank the top. The only one that is not belong to the Marvel univers is the Harry Potter series. DCU only rank NO.6 even thought its' reputation is big as Marvel. Does it mean DCU fans are more likely to discuss it on internet rather than writing some fans story to demostrate their understanding about the plot and character?

# %%
from IPython.display import IFrame
IFrame('favorite films.html', width=800, height=400)
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="favorite films.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
df2 = pd.DataFrame(all_film)

# %%
for index, row in df2.iterrows():
    if len(row['year']) > 4:
        df2.drop(index, inplace=True)

# %%
pd_df = df2['year'].value_counts().reset_index().sort_values(by='index')[:-3]

# %%
from pyecharts import Line

line = Line("films by year")
line.add("films by year", years, values) #, mark_line=["average"], mark_point=['max','min'])
xAxis = line._option['xAxis'][0]
xAxis['type'] = 'value'
xAxis['min'] = min(years)
xAxis['max'] = max(years)
line.render()

# %% [markdown]
# **How classic are some films?**
#
# One buddy wrote a story of a film produced in 1902!  The name of this film is *A trip to the moon*.  Also we can observe that after 1980, the number of fanwork rise dramatically indicating the blooming of this sub-cultrue. And the number of fanworks rise to 107 in 2000 due to the 20 and 30 something. We all know that is because Millennium Generation is kin to the subcultrue.

# %%
from IPython.display import IFrame
IFrame('render.html', width=800, height=400)
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="render.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
