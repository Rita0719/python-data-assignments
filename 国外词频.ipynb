# %%
import jieba
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
from wordcloud import WordCloud
import xlrd
import csv
from os import sys
import pandas as pd

# %%
df = pd.read_csv('keywords.csv',encoding = 'gb2312')
df
# Out:
#      keyword  frequency
# 0         旅行        202
# 1          中         66
# 2          过         45
# 3          拍         44
# 4          吃         42
# 5         一个         38
# 6         怎样         34
# 7         体验         33
# 8         喜欢         32
# 9         觉得         32
# 10        地方         31
# 11        旅途         29
# 12         呢         28
# 13        孩子         24
# 14        照片         24
# 15         带         22
# 16        你们         22
# 17        自驾         21
# 18         多         21
# 19       有没有         20
# 20        特别         20
# 21        拍照         19
# 22        出去         19
# 23         看         18
# 24        自己         18
# 25        摄影         18
# 26        为了         18
# 27        选择         18
# 28        适合         17
# 29        旅游         17
# ...      ...        ...
# 1558      房车          1
# 1559     习惯性          1
# 1560     家里人          1
# 1561    保持联系          1
# 1562      居然          1
# 1563      妈宝          1
# 1564     难道说          1
# 1565      这是          1
# 1566      独立          1
# 1567       表          1
# 1568      时会          1
# 1569      去逛          1
# 1570      中要          1
# 1571      照顾          1
# 1572     小朋友          1
# 1573     自驾车          1
# 1574       型          1
# 1575      优势          1
# 1576       冷          1
# 1577      室外          1
# 1578      组队          1
# 1579      囤货          1
# 1580       咋          1
# 1581       劝          1
# 1582     冤枉钱          1
# 1583      有效          1
# 1584      最值          1
# 1585     哈利波          1
# 1586      迷你          1
# 1587      骄傲          1
#
# [1588 rows x 2 columns]

# %%
keyword = df['keyword'].tolist()

# %%
from pyecharts import WordCloud
keyword = df['keyword']
value = df['frequency']
wordcloud = WordCloud(width=1300, height=620)
wordcloud.add('问答', keyword,value,word_size_range=[40, 100],
              shape='cricle',word_gap= 10)
wordcloud.render()
wordcloud
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="8e997693f7b34070a56d8a787ba6fee8" style="width:1300px;height:620px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_8e997693f7b34070a56d8a787ba6fee8 = echarts.init(document.getElementById('8e997693f7b34070a56d8a787ba6fee8'), 'light', {renderer: 'canvas'});
#
# var option_8e997693f7b34070a56d8a787ba6fee8 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 5682774,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "\u95ee\u7b54",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 10,
#             "sizeRange": [
#                 40,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u65c5\u884c",
#                     "value": 202,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(158,82,139)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d",
#                     "value": 66,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(80,41,95)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8fc7",
#                     "value": 45,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(90,59,52)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u62cd",
#                     "value": 44,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(71,84,124)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5403",
#                     "value": 42,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(159,0,11)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e00\u4e2a",
#                     "value": 38,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(103,0,68)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u600e\u6837",
#                     "value": 34,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(39,42,40)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f53\u9a8c",
#                     "value": 33,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(2,136,69)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u559c\u6b22",
#                     "value": 32,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(114,131,105)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u89c9\u5f97",
#                     "value": 32,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(157,14,50)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5730\u65b9",
#                     "value": 31,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(111,49,43)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65c5\u9014",
#                     "value": 29,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(126,28,122)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5462",
#                     "value": 28,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(143,143,112)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b69\u5b50",
#                     "value": 24,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(85,144,48)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7167\u7247",
#                     "value": 24,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(5,16,70)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e26",
#                     "value": 22,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(107,136,86)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f60\u4eec",
#                     "value": 22,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(107,144,5)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u81ea\u9a7e",
#                     "value": 21,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(107,115,39)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u591a",
#                     "value": 21,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(0,49,11)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6709\u6ca1\u6709",
#                     "value": 20,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(5,120,118)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7279\u522b",
#                     "value": 20,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(114,150,24)"
#                         }
#                     }
