# %%
list1=['/Users/Rita/Desktop/assignment0/trade-wars-news1.txt','/Users/Rita/Desktop/assignment0/trade-wars-news2.txt','/Users/Rita/Desktop/assignment0/trade-wars-news3.txt','/Users/Rita/Desktop/assignment0/trade-wars-news4.txt','/Users/Rita/Desktop/assignment0/trade-wars-news5.txt']
f=open(list1[0],'r')
strings=f.read()
words=strings.split()
for word in words:
    print('{}-{}times'.format(word,words.count(word)))
    
from collections import Counter
print (Counter(words).most_common (15))
list2=Counter(words).most_common ()

headers = ['word','num']
from csv import*
import csv
with open('list.csv','w',newline='')as f:
 f_csv=csv.writer(f)
 if(headers):
    f_csv.writerow(headers)
    if(list2):
        f_csv.writerows(list2)
# Out:
# “Utterly-1times
# messed-2times
# up-5times
# my-5times
# life”:-1times
# What-1times
# Chinese-10times
# people-3times
# really-1times
# think-1times
# of-26times
# the-70times
# trade-15times
# war-8times
# The-8times
# Guardian-1times
# By-1times
# Echo-1times
# HuangOctober-1times
# 9,-1times
# 2018-1times
# China’s-8times
# ardent-1times
# determination-1times
# to-30times
# win-1times
# the-70times
# trade-15times
# war-8times
# might-1times
# not-2times
# have-7times
# all-3times
# the-70times
# public-1times
# support-1times
# it-7times
# would-2times
# like.-1times
# Since-1times
# the-70times
# US-7times
# and-14times
# China-5times
# entered-1times
# a-21times
# trade-15times
# war-8times
# in-23times
# earnest-1times
# this-7times
# year,-3times
# both-1times
# sides-1times
# have-7times
# been-5times
# going-4times
# tit-for-tat-1times
# with-5times
# increasing-2times
# tariffs-5times
# on-7times
# goods.-2times
# The-8times
# US-7times
# has-7times
# put-2times
# new-6times
# tariffs-5times
# on-7times
# $250-1times
# billion-2times
# in-23times
# Chinese-10times
# imports,-1times
# while-2times
# China-5times
# has-7times
# done-1times
# the-70times
# same-1times
# to-30times
# $110-1times
# billion-2times
# worth-1times
# of-26times
# US-7times
# goods.-2times
# And-1times
# while-2times
# China’s-8times
# running-1times
# out-3times
# of-26times
# US-7times
# goods-3times
# to-30times
# keep-2times
# the-70times
# retaliation-1times
# going,-1times
# its-2times
# strongest-1times
# weapon-1times
# in-23times
# this-7times
# “war-1times
# of-26times
# national-2times
# fate”-1times
# with-5times
# the-70times
# US-7times
# is-8times
# the-70times
# spirit-2times
# of-26times
# the-70times
# Chinese-10times
# people,-1times
# according-1times
# to-30times
# state-1times
# media.-1times
# “The-3times
# heroism-1times
# of-26times
# ‘being-1times
# the-70times
# first-4times
# to-30times
# show-1times
# concern-1times
# and-14times
# the-70times
# last-3times
# to-30times
# enjoy-1times
# oneself’-1times
# has-7times
# always-1times
# run-2times
# through-1times
# Chinese-10times
# blood,-1times
# which-2times
# also-5times
# includes-1times
# the-70times
# spirit-2times
# of-26times
# ‘sacrificing-1times
# one’s-1times
# interest-1times
# for-9times
# the-70times
# greater-1times
# good-1times
# of-26times
# the-70times
# public,'”-1times
# said-6times
# an-2times
# opinion-1times
# piece-1times
# (link-7times
# in-23times
# Chinese)-4times
# posted-1times
# by-4times
# the-70times
# state-run-1times
# People’s-1times
# Daily-1times
# on-7times
# July-1times
# 10.-1times
# “Facing-1times
# this-7times
# ‘war-1times
# of-26times
# national-2times
# fate,’-1times
# Chinese-10times
# are-9times
# deeply-2times
# aware-1times
# that-10times
# ‘there’s-1times
# no-1times
# home-1times
# without-1times
# a-21times
# country,’-1times
# so-4times
# they-3times
# are-9times
# willing-1times
# to-30times
# bear-1times
# temporary-1times
# losses.”-1times
# That-1times
# comment-2times
# doesn’t-1times
# acknowledge-1times
# how-2times
# painful-1times
# the-70times
# trade-15times
# war-8times
# could-3times
# become-1times
# for-9times
# common-1times
# people.-2times
# Economists-1times
# estimate-1times
# that-10times
# if-3times
# the-70times
# latest-1times
# Chinese-10times
# goods-3times
# to-30times
# be-5times
# added-1times
# to-30times
# the-70times
# trade-15times
# war-8times
# see-2times
# tariffs-5times
# go-1times
# up-5times
# to-30times
# 25%-1times
# next-2times
# year,-3times
# it-7times
# could-3times
# shave-1times
# half-1times
# a-21times
# percentage-1times
# point-1times
# off-1times
# China’s-8times
# growth.-1times
# Online,-1times
# people-3times
# are-9times
# sharing-1times
# how-2times
# they’re-1times
# experiencing-1times
# the-70times
# impacts-1times
# so-4times
# far,-1times
# and-14times
# worrying-2times
# about-3times
# what’s-1times
# to-30times
# come.-1times
# Stocks-1times
# tumble,-1times
# yuan-2times
# devalues-1times
# On-1times
# Monday-1times
# (Oct.7),-1times
# the-70times
# first-4times
# day-2times
# after-2times
# the-70times
# Golden-1times
# Week-1times
# holiday,-1times
# Chinese-10times
# stocks-1times
# fell-2times
# sharply.-1times
# The-8times
# benchmark-1times
# Shanghai-1times
# Composite-1times
# Index-1times
# fell-2times
# 3.7%—its-1times
# biggest-1times
# single-day-1times
# loss-1times
# (paywall)-2times
# in-23times
# more-5times
# than-5times
# three-2times
# months.-1times
# The-8times
# stock-5times
# tumble-2times
# came-1times
# a-21times
# day-2times
# after-2times
# China’s-8times
# central-1times
# bank-1times
# announced-1times
# that-10times
# it-7times
# would-2times
# cut-1times
# the-70times
# reserve-1times
# requirement-1times
# ratio-1times
# for-9times
# commercial-1times
# banks-1times
# for-9times
# the-70times
# fourth-1times
# time-2times
# this-7times
# year—a-1times
# move-1times
# seen-1times
# as-2times
# trying-1times
# to-30times
# boost-1times
# the-70times
# economy-3times
# by-4times
# increasing-2times
# liquidity-1times
# amid-1times
# the-70times
# trade-15times
# war.-2times
# In-4times
# general,-1times
# China’s-8times
# stock-5times
# markets-1times
# haven’t-2times
# been-5times
# (paywall)-2times
# taking-1times
# the-70times
# trade-15times
# war-8times
# in-23times
# stride.-1times
# “This-1times
# has-7times
# been-5times
# a-21times
# tough-1times
# year-1times
# for-9times
# me.-1times
# I-6times
# haven’t-2times
# received-1times
# payments-1times
# on-7times
# several-1times
# projects-1times
# because-3times
# of-26times
# stock-5times
# bursts,”-1times
# wrote-4times
# a-21times
# user-4times
# (link-7times
# in-23times
# Chinese)-4times
# of-26times
# social-1times
# media-1times
# platform-1times
# Weibo,-2times
# who-3times
# identified-1times
# himself-1times
# as-2times
# working-1times
# at-2times
# a-21times
# securities-1times
# firm-1times
# in-23times
# Beijing.-1times
# “The-3times
# stock-5times
# market’s-1times
# tumble-2times
# and-14times
# the-70times
# trade-15times
# war-8times
# have-7times
# killed-1times
# many-1times
# projects.-1times
# When-1times
# I-6times
# returned-1times
# home,-1times
# the-70times
# village-1times
# officials-1times
# asked-3times
# me-1times
# how’s-1times
# my-5times
# work-1times
# so-4times
# far-1times
# this-7times
# year.-2times
# My-1times
# answer,-1times
# sadly,-1times
# was-1times
# this—deleveraging,-1times
# bad-1times
# stock-5times
# performance,-1times
# and-14times
# the-70times
# trade-15times
# war-8times
# have-7times
# utterly-1times
# messed-2times
# up-5times
# my-5times
# life.”-1times
# REUTERS/MARIANA-1times
# BAZO-1times
# Looking-1times
# for-9times
# new-6times
# markets.-1times
# The-8times
# devalued-1times
# yuan-2times
# has-7times
# also-5times
# worried-1times
# many.-1times
# While-1times
# it-7times
# could-3times
# help-1times
# exporters-1times
# by-4times
# making-1times
# their-2times
# goods-3times
# more-5times
# competitive,-1times
# it-7times
# makes-1times
# life-1times
# tougher-1times
# for-9times
# people-3times
# who-3times
# need-1times
# foreign-3times
# currency,-1times
# for-9times
# example-1times
# families-1times
# of-26times
# the-70times
# hundreds-1times
# of-26times
# thousands-1times
# of-26times
# Chinese-10times
# studying-1times
# abroad.-1times
# “We-1times
# are-9times
# now-1times
# kneeling-1times
# to-30times
# the-70times
# trade-15times
# war.-2times
# It’s-1times
# hard-1times
# to-30times
# see-2times
# that-10times
# the-70times
# RMB-1times
# [renminbi]-1times
# can-1times
# be-5times
# stable-1times
# in-23times
# the-70times
# near-1times
# term.-1times
# Looks-1times
# like-1times
# the-70times
# Great-1times
# Depression-1times
# is-8times
# going-4times
# to-30times
# arrive,”-1times
# said-6times
# a-21times
# Weibo-1times
# comment-2times
# (link-7times
# in-23times
# Chinese).-3times
# Snacks,-1times
# oil-3times
# prices-2times
# up-5times
# Treats-1times
# are-9times
# suddenly-1times
# more-5times
# expensive-2times
# due-1times
# to-30times
# tariffs,-2times
# and-14times
# so-4times
# are-9times
# daily-1times
# necessities.-1times
# “I-3times
# ran-1times
# out-3times
# of-26times
# nuts-3times
# yesterday-1times
# and-14times
# wanted-1times
# to-30times
# top-1times
# up-5times
# my-5times
# stock,”-1times
# wrote-4times
# a-21times
# female-1times
# user-4times
# (link-7times
# in-23times
# Chinese)-4times
# based-2times
# in-23times
# northern-1times
# Hebei-1times
# province,-1times
# but-1times
# she-2times
# found-1times
# the-70times
# nuts-3times
# she’s-1times
# used-1times
# to-30times
# eating-1times
# every-1times
# day,-1times
# including-1times
# pecans,-1times
# commonly-1times
# sourced-1times
# from-4times
# the-70times
# US,-3times
# cost-1times
# her-1times
# more.-1times
# “I-3times
# asked-3times
# the-70times
# shop-1times
# owner,-1times
# ‘Why-1times
# is-8times
# it-7times
# more-5times
# expensive-2times
# than-5times
# last-3times
# time?’-1times
# The-8times
# owner-1times
# said-6times
# it’s-1times
# because-3times
# of-26times
# the-70times
# trade-15times
# war,”-1times
# she-2times
# continued,-1times
# “And-1times
# I-6times
# asked-3times
# him,-1times
# ‘What’s-1times
# the-70times
# relationship?’-1times
# He-1times
# said-6times
# that-10times
# he-2times
# had-1times
# imported-1times
# lots-1times
# of-26times
# the-70times
# nuts-3times
# from-4times
# overseas.-1times
# This-2times
# is-8times
# the-70times
# first-4times
# time-2times
# I-6times
# feel-1times
# the-70times
# impact-1times
# of-26times
# the-70times
# trade-15times
# war.”-1times
# As-1times
# for-9times
# Maine-1times
# lobster,-1times
# forget-1times
# about-3times
# it.-1times
# Chinese-10times
# drivers-1times
# are-9times
# also-5times
# feeling-1times
# the-70times
# pinch,-1times
# with-5times
# China-5times
# putting-1times
# tariffs-5times
# on-7times
# US-7times
# oil-3times
# imports-1times
# in-23times
# August.-1times
# “I’ve-1times
# deeply-2times
# felt-1times
# that-10times
# the-70times
# economic-2times
# environment-1times
# is-8times
# not-2times
# good.-1times
# This-2times
# year,-3times
# there’s-2times
# peer-to-peer-1times
# lending-1times
# and-14times
# illegal-1times
# money-raising-1times
# crackdown,-1times
# which-2times
# also-5times
# bled-1times
# out-3times
# a-21times
# bunch-1times
# of-26times
# people.-2times
# Now-1times
# the-70times
# drop-1times
# has-7times
# come-1times
# to-30times
# the-70times
# real-1times
# estate-1times
# market….-1times
# then-3times
# there’s-2times
# the-70times
# trade-15times
# war,-1times
# and-14times
# oil-3times
# prices-2times
# keep-2times
# going-4times
# up.-2times
# It-1times
# won’t-1times
# be-5times
# long-1times
# before-1times
# I-6times
# can’t-1times
# afford-1times
# to-30times
# run-2times
# my-5times
# car,”-1times
# wrote-4times
# a-21times
# user-4times
# (link-7times
# in-23times
# Chinese).-3times
# Small-1times
# businesses-1times
# may-1times
# be-5times
# harder-1times
# hit-1times
# than-5times
# larger-1times
# ones.-1times
# The-8times
# most-2times
# recent-2times
# Caixin-1times
# manufacturing-2times
# Purchasing-1times
# Managers-1times
# Index,-1times
# a-21times
# better-1times
# gauge-1times
# of-26times
# sentiment-1times
# at-2times
# smaller,-1times
# private-1times
# firms-1times
# than-5times
# the-70times
# official-1times
# manufacturing-2times
# PMI,-1times
# declined-1times
# from-4times
# 50.6-1times
# in-23times
# August-1times
# to-30times
# 50-2times
# last-3times
# month,-1times
# the-70times
# lowest-1times
# level-1times
# in-23times
# more-5times
# than-5times
# a-21times
# year.-2times
# A-1times
# number-1times
# below-1times
# 50-2times
# indicates-1times
# a-21times
# contraction.-1times
# REUTERS-1times
# In-4times
# response-1times
# to-30times
# US-7times
# tariffs,-2times
# China-5times
# has-7times
# put-2times
# tariffs-5times
# on-7times
# American-2times
# soybean-1times
# imports.-1times
# Pessimism-1times
# about-3times
# the-70times
# new-6times
# NAFTA-2times
# People-1times
# aren’t-1times
# optimistic-1times
# the-70times
# pressure-1times
# on-7times
# China’s-8times
# economy-3times
# will-1times
# ease-1times
# up.-2times
# In-4times
# fact,-1times
# the-70times
# new-6times
# North-1times
# American-2times
# Free-1times
# Trade-2times
# Agreement-1times
# renegotiated-1times
# by-4times
# the-70times
# US,-3times
# Mexico,-1times
# and-14times
# Canada—now-1times
# with-5times
# a-21times
# brand-new-1times
# acronym—shows-1times
# the-70times
# formation-1times
# of-26times
# a-21times
# front-1times
# against-1times
# China,-1times
# some-1times
# online-1times
# commenters-1times
# noted.-1times
# “Why-1times
# is-8times
# the-70times
# Chinese-10times
# economy-3times
# going-4times
# to-30times
# be-5times
# difficult-1times
# in-23times
# the-70times
# next-2times
# six-1times
# months?”-1times
# wrote-4times
# a-21times
# male-1times
# user-4times
# (link-7times
# in-23times
# Chinese)-4times
# of-26times
# micro-blogging-1times
# site-1times
# Weibo,-2times
# based-2times
# in-23times
# China’s-8times
# southwestern-1times
# Sichuan-1times
# province.-1times
# His-1times
# argument-1times
# that-10times
# the-70times
# elements-1times
# that-10times
# have-7times
# been-5times
# key-1times
# to-30times
# driving-1times
# China’s-8times
# economic-2times
# growth-1times
# in-23times
# recent-2times
# years—including-1times
# infrastructure,-1times
# foreign-3times
# trade,-2times
# and-14times
# domestic-1times
# demands—have-1times
# all-3times
# shown-1times
# worrying-2times
# signs.-1times
# “In-1times
# terms-1times
# of-26times
# foreign-3times
# trade,-2times
# this-7times
# is-8times
# the-70times
# most-2times
# worrying,”-1times
# he-2times
# wrote.-1times
# “The-3times
# Americans-1times
# are-9times
# launching-1times
# trade-15times
# wars-1times
# worldwide-1times
# because-3times
# they-3times
# want-1times
# to-30times
# bypass-1times
# the-70times
# WTO-1times
# [World-1times
# Trade-2times
# Organization]-1times
# and-14times
# build-1times
# something-1times
# new.-1times
# At-1times
# the-70times
# end-1times
# of-26times
# September,-1times
# the-70times
# US,-3times
# Canada-1times
# and-14times
# Mexico-2times
# signed-1times
# a-21times
# new-6times
# cooperation-1times
# agreement.-1times
# The-8times
# agreement-2times
# said-6times
# if-3times
# a-21times
# ‘non-market-oriented-2times
# economy‘-1times
# wants-1times
# to-30times
# enter-1times
# their-2times
# market,-1times
# it-7times
# needs-1times
# the-70times
# approval-1times
# of-26times
# all-3times
# the-70times
# three-2times
# countries…-1times
# Everyone-1times
# knows-1times
# who-3times
# this-7times
# ‘non-market-oriented-2times
# economy’-1times
# is.”-1times
# (The-1times
# new-6times
# NAFTA-2times
# asks-1times
# countries-1times
# in-23times
# the-70times
# agreement-2times
# to-30times
# notify-1times
# each-1times
# other-1times
# if-3times
# they-3times
# are-9times
# to-30times
# have-7times
# trade-15times
# deal-1times
# talks-1times
# with-5times
# a-21times
# “non-market”-1times
# economy,-1times
# and-14times
# also-5times
# give-1times
# one-1times
# another-2times
# a-21times
# say-1times
# in-23times
# the-70times
# deal.)-1times
# “Americans-1times
# have-7times
# been-5times
# building-1times
# an-2times
# anti-China-1times
# circle.-1times
# In-4times
# the-70times
# first-4times
# round,-1times
# the-70times
# Mexico-2times
# gave-1times
# in,-1times
# then-3times
# Canada.-1times
# I-6times
# am-1times
# afraid-1times
# that-10times
# the-70times
# third-1times
# round-1times
# is-8times
# Japan,-1times
# then-3times
# Europe,”-1times
# said-6times
# another-2times
# (link-7times
# in-23times
# Chinese).-3times
# “I-3times
# highly-1times
# suggest-1times
# that-10times
# China-5times
# should-1times
# make-1times
# major-1times
# adjustments-1times
# to-30times
# its-2times
# current-1times
# policies-1times
# instead-1times
# of-26times
# listening-1times
# to-30times
# the-70times
# opinions-1times
# from-4times
# so-called-1times
# elites.”-1times
# [('the', 70), ('to', 30), ('of', 26), ('in', 23), ('a', 21), ('trade', 15), ('and', 14), ('Chinese', 10), ('that', 10), ('for', 9), ('are', 9), ('war', 8), ('The', 8), ('China’s', 8), ('is', 8)]
